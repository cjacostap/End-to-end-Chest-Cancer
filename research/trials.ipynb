# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_product(x = 2, y = "3")
#
# File d:\Softwares\anaconda3\envs\cancer\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x0000022D27CEB1F0> does not match annotation type <class 'int'>

# %% [markdown]
# ### Download data from gdrive

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1d88rzFAF9jX3pARwvnRLzqlM5jJWAy9f/view?usp=drive_link"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1d88rzFAF9jX3pARwvnRLzqlM5jJWAy9f'

# %%
# prefix = 'https://drive.google.com/uc?export=download&id='
# gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File ~/miniconda3/envs/cancer/lib/python3.8/site-packages/gdown/download.py:267, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, fuzzy, resume, format, user_agent, log_messages)
#     266 try:
# --> 267     url = get_url_from_gdrive_confirmation(res.text)
#     268 except FileURLRetrievalError as e:
#
# File ~/miniconda3/envs/cancer/lib/python3.8/site-packages/gdown/download.py:55, in get_url_from_gdrive_confirmation(contents)
#      54 if not url:
# ---> 55     raise FileURLRetrievalError(
#      56         "Cannot retrieve the public link of the file. "
#      57         "You may need to change the permission to "
#      58         "'Anyone with the link', or have had many accesses. "
#      59         "Check FAQ in https://github.com/wkentaro/gdown?tab=readme-ov-file#faq.",
#      60     )
# ...

# %%
# CA 20251217: Si usas la librería gdown, no necesitas construir el prefijo manualmente
 
import gdown

# La URL tal cual la copias de Drive
url = "https://drive.google.com/file/d/1d88rzFAF9jX3pARwvnRLzqlM5jJWAy9f/view?usp=drive_link"

# gdown detecta automáticamente si es un enlace de Drive y extrae el ID por ti
output = "Chest-CT-Scan-data.zip"
gdown.download(url, output, quiet=False)
# Out:
# /Users/cjacosta/miniconda3/envs/cancer/lib/python3.8/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1d88rzFAF9jX3pARwvnRLzqlM5jJWAy9f
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1d88rzFAF9jX3pARwvnRLzqlM5jJWAy9f/view?usp=drive_link
# To: /Users/cjacosta/Repositorio/MLOPS/End-to-end-Chest-Cancer/research/Chest-CT-Scan-data.zip
# 8.98kB [00:00, 2.63MB/s]
# 'Chest-CT-Scan-data.zip'
